# %% [markdown]
# <a href="https://colab.research.google.com/github/VivianaMoreno07/pandas_/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import panda as pd

encuesta= pd.Dataframe(
    {
        "Julia":["me gusto", "fue horrible"],
        "pedro":["Fue delicioso", "No estuvo mal"],
    }
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9149e8b39407> in <cell line: 1>()
# ----> 1 import panda as pd
#       2
#       3 encuesta= pd.Dataframe(
#       4     {
#       5         "Julia":["me gusto", "fue horrible"],
#
# ModuleNotFoundError: No module named 'panda'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Cargar archivos CSV en un dataframe

# %%
import pandas as pd

miCSV=pd.read_csv("datos.csv.txt")
miCSV.shape
miCSV.head()
# Out:
#    estudiante_1   estudiante_2   estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %% [markdown]
# Taller

# %%
import pandas as pd

miAmazon=pd.read_csv("amazon_prime_users.csv")
miAmazon.shape
miAmazon.head()
# Out:
#    User ID              Name                   Email Address  \
# 0        1     Ronald Murphy      williamholland@example.com
# 1        2       Scott Allen             scott22@example.org
# 2        3  Jonathan Parrish            brooke16@example.org
# 3        4    Megan Williams         elizabeth31@example.net
# 4        5     Kathryn Brown  pattersonalexandra@example.org
#
#              Username Date of Birth  Gender        Location  \
# 0      williamholland    1953-06-03    Male  Rebeccachester
# 1             scott22    1978-07-08    Male   Mcphersonview
# 2            brooke16    1994-12-06  Female       Youngfort
# 3         elizabeth31    1964-12-22  Female    Feliciashire
# 4  pattersonalexandra    1961-06-04    Male    Port Deborah
#
#   Membership Start Date Membership End Date Subscription Plan  \
# 0            2024-01-15          2025-01-14            Annual
# 1            2024-01-07          2025-01-06           Monthly
# ...

# %%
miAmazon.describe()
# Out:
#           User ID  Feedback/Ratings  Customer Support Interactions
# count  2500.00000       2500.000000                    2500.000000
# mean   1250.50000          4.004760                       4.951600
# std     721.83216          0.580769                       3.191572
# min       1.00000          3.000000                       0.000000
# 25%     625.75000          3.500000                       2.000000
# 50%    1250.50000          4.000000                       5.000000
# 75%    1875.25000          4.500000                       8.000000
# max    2500.00000          5.000000                      10.000000

# %%
miAmazon.rename(columns={"interactions":"interacciones"})
# Out:
#       User ID              Name                   Email Address  \
# 0           1     Ronald Murphy      williamholland@example.com
# 1           2       Scott Allen             scott22@example.org
# 2           3  Jonathan Parrish            brooke16@example.org
# 3           4    Megan Williams         elizabeth31@example.net
# 4           5     Kathryn Brown  pattersonalexandra@example.org
# ...       ...               ...                             ...
# 2495     2496     Michael Lopez     williamsroberto@example.org
# 2496     2497   Matthew Woodard             lkaiser@example.com
# 2497     2498     Morgan Barnes        erikaholland@example.net
# 2498     2499    Gina Castaneda        reedcourtney@example.net
# 2499     2500    Mark Nicholson         martinisaac@example.net
#
#                 Username Date of Birth  Gender          Location  \
# 0         williamholland    1953-06-03    Male    Rebeccachester
# ...
